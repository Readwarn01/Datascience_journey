# %%
import pandas as pd

# %% [markdown]
# ## Data structure or objects pandas use to store and manipulate data
#
# - Series >
#     A single column of data with labels (called index)
#
# - DataFrames >
#     A 2-Dimensional table of data made up of rows and column

# %%
#Series - 1 Dimensiional
Brand_Colours = pd.Series(["Yellow and Red", "Balck and Green", "Yellow", "Blue"])
Brand_Colours
# Out:
# 0     Yellow and Red
# 1    Balck and Green
# 2             Yellow
# 3               Blue
# dtype: str

# %%
#Series - 1 Dimensiional
Company = pd.Series(["Pwc", "Deloitte", "EY", "KPMG"])
Company
# Out:
# 0         Pwc
# 1    Deloitte
# 2          EY
# 3        KPMG
# dtype: str

# %%
#DataFrames - 2 Dimensiional

Big4_Data = pd.DataFrame ({"Company Name": Company, "Brand Colour": Brand_Colours})
Big4_Data
# Out:
#   Company Name     Brand Colour
# 0          Pwc   Yellow and Red
# 1     Deloitte  Balck and Green
# 2           EY           Yellow
# 3         KPMG             Blue

# %%
#To import data

car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-car-sales.csv", index = False)

# %%
export_car_sales = pd.read_csv("exported-car-sales.csv")
export_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Attributes
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
#Attributes
car_column = car_sales.columns
car_column
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.describe(include="all")
# Out:
#           Make Colour  Odometer (KM)      Doors       Price
# count       10     10      10.000000  10.000000          10
# unique       4      5            NaN        NaN           9
# top     Toyota  White            NaN        NaN  $7,000.00
# freq         4      4            NaN        NaN           2
# mean       NaN    NaN   78601.400000   4.000000         NaN
# std        NaN    NaN   61983.471735   0.471405         NaN
# min        NaN    NaN   11179.000000   3.000000         NaN
# 25%        NaN    NaN   35836.250000   4.000000         NaN
# 50%        NaN    NaN   57369.000000   4.000000         NaN
# 75%        NaN    NaN   96384.500000   4.000000         NaN
# max        NaN    NaN  213095.000000   5.000000         NaN

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_prices = pd.Series([10000,5656,38363,737373])
car_prices.mean(numeric_only = True)
# Out:
# np.float64(197848.0)

# %%
car_prices.sum()
# Out:
# np.int64(791392)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00 $5,000.00 $7,000.00 $22,000.00 $3,50...
# dtype: object

# %%
car_sales["Doors"].sum(numeric_only = True)
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %%
fugaz = pd.Series(["First Bank", "United Bank of Africa", "Guarantee Trust Bank", "Access Bank", "Zenith Bank"])
fugaz
# Out:
# 0               First Bank
# 1    United Bank of Africa
# 2     Guarantee Trust Bank
# 3              Access Bank
# 4              Zenith Bank
# dtype: str

# %%
salary_data = pd.Series(["300k-500k", "500k-750k", "700k-900k", "707k-945k","850k-1,000,000"])
salary_data
# Out:
# 0         300k-500k
# 1         500k-750k
# 2         700k-900k
# 3         707k-945k
# 4    850k-1,000,000
# dtype: str

# %%
employment_opportunity_data = pd.DataFrame({"Bank Name":fugaz, "salary_range": salary_data})
employment_opportunity_data
# Out:
#                Bank Name    salary_range
# 0             First Bank       300k-500k
# 1  United Bank of Africa       500k-750k
# 2   Guarantee Trust Bank       700k-900k
# 3            Access Bank       707k-945k
# 4            Zenith Bank  850k-1,000,000

# %%
employment_opportunity_data.to_csv("Exported employment_opportunity_data", index=False)

# %%
employment_opportunity = pd.read_csv("Exported employment_opportunity_data")
employment_opportunity
# Out:
#                Bank Name    salary_range
# 0             First Bank       300k-500k
# 1  United Bank of Africa       500k-750k
# 2   Guarantee Trust Bank       700k-900k
# 3            Access Bank       707k-945k
# 4            Zenith Bank  850k-1,000,000

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
##loc and iloc

#loc refers to index

Animals = pd.Series(["Dog","Cat","Rabbit","Cow","Ram"], index = [2,4,6,8,6])
Animals
# Out:
# 2       Dog
# 4       Cat
# 6    Rabbit
# 8       Cow
# 6       Ram
# dtype: str

# %%
Animals.loc[6]
# Out:
# 6    Rabbit
# 6       Ram
# dtype: str

# %%
Animals.loc[4]
# Out:
# 'Cat'

# %%
car_sales.loc[4]
# Out:
# Make                 Nissan
# Colour                White
# Odometer (KM)        213095
# Doors                     4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
##iloc
#iloc refers to position


Animals.iloc[4]
# Out:
# 'Ram'

# %%
Animals.iloc[:4]
# Out:
# 2       Dog
# 4       Cat
# 6    Rabbit
# 8       Cow
# dtype: str

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
##Groupby

car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Manipulating Data in Pandas

# %%
car_sales["Make"] = car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %%
car_sales["Make"] = car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"] = car_sales["Make"].str.capitalize()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     Bmw  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
#Column from series

seat_column = pd.Series([5,10])

#Column from series
car_sales["Seats"] = seat_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00    10.0
# 2  Toyota   Blue          32549      3   $7,000.00     NaN
# 3     Bmw  Black          11179      5  $22,000.00     NaN
# 4  Nissan  White         213095      4   $3,500.00     NaN
# 5  Toyota  Green          99213      4   $4,500.00     NaN
# 6   Honda   Blue          45698      4   $7,500.00     NaN
# 7   Honda   Blue          54738      4   $7,000.00     NaN
# 8  Toyota  White          60000      4   $6,250.00     NaN
# 9  Nissan  White          31600      4   $9,700.00     NaN

# %%
car_sales.fillna(5)
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00    10.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     5.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0
# 8  Toyota  White          60000      4   $6,250.00     5.0
# 9  Nissan  White          31600      4   $9,700.00     5.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00    10.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     5.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0
# 8  Toyota  White          60000      4   $6,250.00     5.0
# 9  Nissan  White          31600      4   $9,700.00     5.0

# %%
#Column from python lists

fuel_economy = [7.5, 7.9, 16.0, 17.9, 16.8,7.5, 7.9, 16.0, 17.9, 16.8]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Odometer (KM)"]/100*car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8
#
#    Total Fuel Used  Total Fuel Used (L)
# 0        11253.225            11253.225
# 1         6944.021             6944.021
# 2         5207.840             5207.840
# 3         2001.041             2001.041
# 4        35799.960            35799.960
# 5         7440.975             7440.975
# 6         3610.142             3610.142
# 7         8758.080             8758.080
# 8        10740.000            10740.000
# 9         5308.800             5308.800

# %%
car_sales["Number of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8
#
#    Total Fuel Used  Total Fuel Used (L)  Number of Wheels
# 0        11253.225            11253.225                 4
# 1         6944.021             6944.021                 4
# 2         5207.840             5207.840                 4
# 3         2001.041             2001.041                 4
# 4        35799.960            35799.960                 4
# 5         7440.975             7440.975                 4
# 6         3610.142             3610.142                 4
# 7         8758.080             8758.080                 4
# 8        10740.000            10740.000                 4
# 9         5308.800             5308.800                 4

# %%
car_sales["Pass Road Safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8
#
#    Total Fuel Used  Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 0        11253.225            11253.225                 4              True
# 1         6944.021             6944.021                 4              True
# 2         5207.840             5207.840                 4              True
# 3         2001.041             2001.041                 4              True
# 4        35799.960            35799.960                 4              True
# 5         7440.975             7440.975                 4              True
# 6         3610.142             3610.142                 4              True
# 7         8758.080             8758.080                 4              True
# 8        10740.000            10740.000                 4              True
# 9         5308.800             5308.800                 4              True

# %%
car_sales = car_sales.drop("Total Fuel Used", axis = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8
#
#    Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 0            11253.225                 4              True
# 1             6944.021                 4              True
# 2             5207.840                 4              True
# 3             2001.041                 4              True
# 4            35799.960                 4              True
# 5             7440.975                 4              True
# 6             3610.142                 4              True
# 7             8758.080                 4              True
# 8            10740.000                 4              True
# 9             5308.800                 4              True

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 9  Nissan  White          31600      4   $9,700.00     5.0            16.8
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 8  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 4  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0            16.0
#
#    Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 9             5308.800                 4              True
# 0            11253.225                 4              True
# 1             6944.021                 4              True
# 8            10740.000                 4              True
# 3             2001.041                 4              True
# 4            35799.960                 4              True
# 6             3610.142                 4              True
# 5             7440.975                 4              True
# 2             5207.840                 4              True
# 7             8758.080                 4              True

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 3     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 0  Toyota  White         150043      4   $4,000.00     5.0             7.5
#
#    Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 3             2001.041                 4              True
# 0            11253.225                 4              True

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors        Price  Seats  \
# 0      9  Nissan  White          31600      4   $9,700.00     5.0
# 1      0  Toyota  White         150043      4   $4,000.00     5.0
# 2      1   Honda    Red          87899      4   $5,000.00    10.0
# 3      8  Toyota  White          60000      4   $6,250.00     5.0
# 4      3     Bmw  Black          11179      5  $22,000.00     5.0
# 5      4  Nissan  White         213095      4   $3,500.00     5.0
# 6      6   Honda   Blue          45698      4   $7,500.00     5.0
# 7      5  Toyota  Green          99213      4   $4,500.00     5.0
# 8      2  Toyota   Blue          32549      3   $7,000.00     5.0
# 9      7   Honda   Blue          54738      4   $7,000.00     5.0
#
#    Fuel per 100KM  Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 0            16.8             5308.800                 4              True
# 1             7.5            11253.225                 4              True
# 2             7.9             6944.021                 4              True
# 3            17.9            10740.000                 4              True
# 4            17.9             2001.041                 4              True
# 5            16.8            35799.960                 4              True
# 6             7.9             3610.142                 4              True
# 7             7.5             7440.975                 4              True
# 8            16.0             5207.840                 4              True
# 9            16.0             8758.080                 4              True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Seats  Fuel per 100KM  \
# 0  Nissan  White          31600      4   $9,700.00     5.0            16.8
# 1  Toyota  White         150043      4   $4,000.00     5.0             7.5
# 2   Honda    Red          87899      4   $5,000.00    10.0             7.9
# 3  Toyota  White          60000      4   $6,250.00     5.0            17.9
# 4     Bmw  Black          11179      5  $22,000.00     5.0            17.9
# 5  Nissan  White         213095      4   $3,500.00     5.0            16.8
# 6   Honda   Blue          45698      4   $7,500.00     5.0             7.9
# 7  Toyota  Green          99213      4   $4,500.00     5.0             7.5
# 8  Toyota   Blue          32549      3   $7,000.00     5.0            16.0
# 9   Honda   Blue          54738      4   $7,000.00     5.0            16.0
#
#    Total Fuel Used (L)  Number of Wheels  Pass Road Safety
# 0             5308.800                 4              True
# 1            11253.225                 4              True
# 2             6944.021                 4              True
# 3            10740.000                 4              True
# 4             2001.041                 4              True
# 5            35799.960                 4              True
# 6             3610.142                 4              True
# 7             7440.975                 4              True
# 8             5207.840                 4              True
# 9             8758.080                 4              True
